# %% [markdown]
# # Mcdonald.

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt 
# %matplotlib inline 
sns.set(color_codes=True)
from pandas import DataFrame

# %%
df = pd.read_csv('Mcdonald+.csv')

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
df.describe().T
# Out:
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# we don't have any null values in the dataset

# %%
df.shape
# Out:
# (260, 24)

# %% [markdown]
# so we have 260 Rows and 24 Columns in given Dataset

# %%
df.head().T
# Out:
#                                             0                  1  \
# Category                            Breakfast          Breakfast
# Item                             Egg McMuffin  Egg White Delight
# Serving Size                   4.8 oz (136 g)     4.8 oz (135 g)
# Calories                                  300                250
# Calories from Fat                         120                 70
# Total Fat                                13.0                8.0
# Total Fat (% Daily Value)                  20                 12
# Saturated Fat                             5.0                3.0
# Saturated Fat (% Daily Value)              25                 15
# Trans Fat                                 0.0                0.0
# Cholesterol                               260                 25
# Cholesterol (% Daily Value)                87                  8
# Sodium                                    750                770
# ...

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df['Category'].nunique()
# Out:
# 9

# %% [markdown]
# We have 9 Types of Foods here

# %%
df['Item'].value_counts()
# Out:
# Big Breakfast (Large Biscuit)                          1
# Frappé Caramel (Large)                                 1
# Big Breakfast with Egg Whites (Large Biscuit)          1
# Hamburger                                              1
# Dr Pepper (Small)                                      1
#                                                       ..
# Caramel Latte (Large)                                  1
# Honey Mustard Snack Wrap (Crispy Chicken)              1
# Iced Caramel Mocha (Large)                             1
# Latte with Sugar Free French Vanilla Syrup (Medium)    1
# Premium Bacon Ranch Salad with Crispy Chicken          1
# Name: Item, Length: 260, dtype: int64

# %%
df['Item'].nunique()
# Out:
# 260

# %%
plt.figure(figsize=(15,5))
df['Category'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The Highest sale is COFFEE&TEA
# The lowest sale is SALADS

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['Carbohydrates (% Daily Value)']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[['Calories','Calories from Fat','Cholesterol','Sodium']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[['Total Fat','Total Fat (% Daily Value)','Dietary Fiber (% Daily Value)','Protein']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[['Vitamin A (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)','Carbohydrates']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[['Saturated Fat','Saturated Fat (% Daily Value)','Sodium (% Daily Value)']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[['Cholesterol (% Daily Value)','Dietary Fiber','Sugars']])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[['Trans Fat','Vitamin C (% Daily Value)']])
# Out:
# <AxesSubplot:>

# %%
df.head().T
# Out:
#                                             0                  1  \
# Category                            Breakfast          Breakfast
# Item                             Egg McMuffin  Egg White Delight
# Serving Size                   4.8 oz (136 g)     4.8 oz (135 g)
# Calories                                  300                250
# Calories from Fat                         120                 70
# Total Fat                                13.0                8.0
# Total Fat (% Daily Value)                  20                 12
# Saturated Fat                             5.0                3.0
# Saturated Fat (% Daily Value)              25                 15
# Trans Fat                                 0.0                0.0
# Cholesterol                               260                 25
# Cholesterol (% Daily Value)                87                  8
# Sodium                                    750                770
# ...

# %% [markdown]
# The outliers are
#
# 1.Calories
#
# 2.Calories from Fat
#
# 3.Total fat
#
# 4.Cholestrol
#
# 5.Cholestrol (% Daily Value)
#
# 6.Calories from Fat
#
# 7.Cholestrol
#
# 8.Cholestrol (% Daily Value)
#
# 9.Total Fat
#
# 10.Total Fat (% Daily Value)
#
# 11.Sodium (% Daily Value)
#
# 12.Sodium

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df['Saturated Fat (% Daily Value)'])
# Out:
# <AxesSubplot:>

# %%
correlation = df.corr()
correlation
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The correlation is taking as 60% then
#
# 1.Calories have correlation with Saturated fat(0.85),Sodium(0.71),cholestrol(0.68),iron(0.64)
#
# 2.Saturated Fat correlation with cholestrol(0.63),trans fat(0.62),Protien(0.6)
#
# 3.Total Fat have correlation with Saturated fat and  Sodium(0.85),protien(0.81),iron(0.71),cholestrol(0.68)
#
# 4.Sodium have correlation with iron and Protien(0.87),Dietary Fiber(0.69)
#
# 5.Cholestral have correlation with iron(0.65),Sodium(0.62)
#
# 6.Dietery Fiber have correlation with iron(0.74)
#
# 7.Charbohydrates have correlation with Sugar(0.76)
#
# 8.Sugar have correlation with Calcium(0.6)
#
# 9.Protien have correlation with iron(0.79)

# %%
df['Cholesterol (% Daily Value)'].head()
# Out:
# 0    87
# 1     8
# 2    15
# 3    95
# 4    16
# Name: Cholesterol (% Daily Value), dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
Category_list = sorted(df['Category'].unique())

# %%
Category_list
# Out:
# ['Beef & Pork',
#  'Beverages',
#  'Breakfast',
#  'Chicken & Fish',
#  'Coffee & Tea',
#  'Desserts',
#  'Salads',
#  'Smoothies & Shakes',
#  'Snacks & Sides']

# %%
type(Category_list)
# Out:
# list

# %%
a = pd.DataFrame(Category_list,columns=[''] )

# %%
a
# Out:
#
# 0         Beef & Pork
# 1           Beverages
# 2           Breakfast
# 3      Chicken & Fish
# 4        Coffee & Tea
# 5            Desserts
# 6              Salads
# 7  Smoothies & Shakes
# 8      Snacks & Sides

# %%
a.index +=1

# %%
a
# Out:
#
# 1         Beef & Pork
# 2           Beverages
# 3           Breakfast
# 4      Chicken & Fish
# 5        Coffee & Tea
# 6            Desserts
# 7              Salads
# 8  Smoothies & Shakes
# 9      Snacks & Sides

# %%
print('\n\n The different food category that are available \n\n',a)
# Out:
#  The different food category that are available
#
#
# 1         Beef & Pork
# 2           Beverages
# 3           Breakfast
# 4      Chicken & Fish
# 5        Coffee & Tea
# 6            Desserts
# 7              Salads
# 8  Smoothies & Shakes
# 9      Snacks & Sides

# %%
b = pd.pivot_table(df,'Cholesterol (% Daily Value)',index = ['Category'])

# %%
b
# Out:
#                     Cholesterol (% Daily Value)
# Category
# Beef & Pork                           28.933333
# Beverages                              0.185185
# Breakfast                             50.952381
# Chicken & Fish                        25.222222
# Coffee & Tea                           9.378947
# Desserts                               4.857143
# Salads                                17.333333
# Smoothies & Shakes                    14.714286
# Snacks & Sides                         6.230769

# %%
Result = b.sort_values(('Cholesterol (% Daily Value)'),ascending = False)

# %%
Result
# Out:
#                     Cholesterol (% Daily Value)
# Category
# Breakfast                             50.952381
# Beef & Pork                           28.933333
# Chicken & Fish                        25.222222
# Salads                                17.333333
# Smoothies & Shakes                    14.714286
# Coffee & Tea                           9.378947
# Snacks & Sides                         6.230769
# Desserts                               4.857143
# Beverages                              0.185185

# %%
Result['Cholesterol (% Daily Value)'].max()
# Out:
# 50.95238095238095

# %% [markdown]
# The maximum % of Cholesterol in a diet (% daily value) is Breakfast(50.95238095238095).

# %%
df['Item'].nunique()
# Out:
# 260

# %%
c = pd.pivot_table(df,'Sodium',index=['Item'])

# %%
c
# Out:
#                                Sodium
# Item
# 1% Low Fat Milk Jug               125
# Apple Slices                        0
# Bacon Buffalo Ranch McChicken    1260
# Bacon Cheddar McChicken          1260
# Bacon Clubhouse Burger           1470
# ...                               ...
# Sweet Tea (Medium)                 10
# Sweet Tea (Small)                  10
# Vanilla Shake (Large)             260
# Vanilla Shake (Medium)            200
# Vanilla Shake (Small)             160
#
# [260 rows x 1 columns]

# %%
Sodium_Result = c.sort_values(('Sodium'),ascending = False)

# %%
Sodium_Result.head()
# Out:
#                                                     Sodium
# Item
# Chicken McNuggets (40 piece)                          3600
# Big Breakfast with Hotcakes and Egg Whites (Lar...    2290
# Big Breakfast with Hotcakes (Large Biscuit)           2260
# Big Breakfast with Hotcakes and Egg Whites (Reg...    2170
# Big Breakfast with Hotcakes (Regular Biscuit)         2150

# %%
df.head().T
# Out:
#                                             0                  1  \
# Category                            Breakfast          Breakfast
# Item                             Egg McMuffin  Egg White Delight
# Serving Size                   4.8 oz (136 g)     4.8 oz (135 g)
# Calories                                  300                250
# Calories from Fat                         120                 70
# Total Fat                                13.0                8.0
# Total Fat (% Daily Value)                  20                 12
# Saturated Fat                             5.0                3.0
# Saturated Fat (% Daily Value)              25                 15
# Trans Fat                                 0.0                0.0
# Cholesterol                               260                 25
# Cholesterol (% Daily Value)                87                  8
# Sodium                                    750                770
# ...

# %%
Sodium_Result['Sodium'].max()
# Out:
# 3600

# %% [markdown]
# The maximum Sodium intake is Chicken McNuggets (40 piece)(3600).

# %%
df['Saturated Fat'].nunique()
# Out:
# 26

# %%
df['Saturated Fat'].head()
# Out:
# 0     5.0
# 1     3.0
# 2     8.0
# 3    10.0
# 4     8.0
# Name: Saturated Fat, dtype: float64

# %%
d = pd.pivot_table(df,'Saturated Fat',index = ['Item'])

# %%
d
# Out:
#                                Saturated Fat
# Item
# 1% Low Fat Milk Jug                      1.5
# Apple Slices                             0.0
# Bacon Buffalo Ranch McChicken            5.0
# Bacon Cheddar McChicken                  7.0
# Bacon Clubhouse Burger                  15.0
# ...                                      ...
# Sweet Tea (Medium)                       0.0
# Sweet Tea (Small)                        0.0
# Vanilla Shake (Large)                   15.0
# Vanilla Shake (Medium)                  12.0
# Vanilla Shake (Small)                   10.0
#
# [260 rows x 1 columns]

# %%
Fat_Result = d.sort_values(('Saturated Fat'), ascending=False)
Fat_Result.head()
# Out:
#                                              Saturated Fat
# Item
# McFlurry with M&M’s Candies (Medium)                  20.0
# Big Breakfast with Hotcakes (Large Biscuit)           20.0
# Chicken McNuggets (40 piece)                          20.0
# Frappé Chocolate Chip (Large)                         20.0
# Double Quarter Pounder with Cheese                    19.0

# %%
Fat_Result['Saturated Fat'].max()
# Out:
# 20.0

# %% [markdown]
# The most amount of Saturated Fat
#
# 1.McFlurry with M&M’s Candies (Medium) (20.0)
#
# 2.Big Breakfast with Hotcakes (Large Biscuit) (20.0)
#
# 3.Chicken McNuggets (40 piece) (20.0)
#
# 4.Frappé Chocolate Chip (Large) (20.0)
